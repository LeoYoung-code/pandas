# %%
import pandas as pd
pd.__version__
# Out:
# '2.1.0'

# %%
download = "/Users/staff/Downloads/"
df = pd.read_excel(download + "team.xlsx")
df.sample(10)  # 随机抽取10
# Out:
#          name team  Q1  Q2  Q3  Q4
# 85       Liam    B   2  80  24  25
# 18    William    C  80  68   3  26
# 6        Acob    B  61  95  94   8
# 37  Sebastian    C   1  14  68  48
# 58      Lewis    B   4  34  77  28
# 44   Benjamin    D  15  88  52  25
# 19        Max    E  97  75  41   3
# 16     Joshua    A  63   4  80  30
# 5      Harlie    C  24  13  87  43
# 97   Lincoln4    C  98  93   1  20

# %%
# df.shape # (100, 6) 查看行数和列数 
# df.info() # 查看索引、数据类型和内存信息 
# df.describe() # 查看数值型列的汇总统计 
# df.dtypes # 查看各字段类型
# df.axes # 显示数据行和列名 
# df.columns # 列名
# df.sample(10)  # 随机抽取10
df.describe()
# Out:
#                Q1          Q2          Q3          Q4
# count  100.000000  100.000000  100.000000  100.000000
# mean    49.200000   52.550000   52.670000   52.780000
# std     29.962603   29.845181   26.543677   27.818524
# min      1.000000    1.000000    1.000000    2.000000
# 25%     19.500000   26.750000   29.500000   29.500000
# 50%     51.500000   49.500000   55.000000   53.000000
# 75%     74.250000   77.750000   76.250000   75.250000
# max     98.000000   99.000000   99.000000   99.000000

# %%
df.set_index('name', inplace=True)
df.sample(10)
# Out:
#          team  Q1  Q2  Q3  Q4
# name
# Arry        C  36  37  37  57
# Lincoln4    C  98  93   1  20
# Reuben      D  70  72  76  56
# Hunter3     D  38  80  82  40
# Daniel      C  50  50  72  61
# Aaron       A  96  75  55   8
# Louie       D  24  84  54  11
# Max         E  97  75  41   3
# Lfie        A   9  10  99  37
# Albert0     B  85  38  41  17

# %%
# df.team
df[['team','Q1','Q2','Q3']]
# Out:
#          team  Q1  Q2  Q3
# name
# Liver       E  89  21  24
# Arry        C  36  37  37
# Ack         A  57  60  18
# Eorge       C  93  96  71
# Oah         D  65  49  61
# ...       ...  ..  ..  ..
# Gabriel     C  48  59  87
# Austin7     C  21  31  30
# Lincoln4    C  98  93   1
# Eli         E  11  74  58
# Ben         E  21  43  41
#
# [100 rows x 4 columns]

# %%
# df.loc['Arry','Q1':'Q4']
df.loc['Eorge':'Alexander','team':'Q4']
# Out:
#           team  Q1  Q2  Q3  Q4
# name
# Eorge        C  93  96  71  78
# Oah          D  65  49  61  86
# Harlie       C  24  13  87  43
# Acob         B  61  95  94   8
# Lfie         A   9  10  99  37
# Reddie       D  64  93  57  72
# Oscar        A  77   9  26  67
# Leo          B  17   4  33  79
# Logan        B   9  89  35  65
# Archie       C  83  89  59  68
# Theo         C  51  86  87  27
# Thomas       B  80  48  56  41
# James        E  48  77  52  11
# Joshua       A  63   4  80  30
# Henry        A  91  15  75  17
# William      C  80  68   3  26
# Max          E  97  75  41   3
# Lucas        A  60  41  77  62
# Ethan        D  79  45  89  88
# Arthur       A  44  53  42  40
# Mason        D  80  96  26  49
# Isaac        E  74  23  28  65
# Harrison     B  89  13  18  75
# Teddy        E  71  91  21  48
# Finley       D  62  73  84  68
# Daniel       C  50  50  72  61
# Riley        E  35  26  59  83
# Edward       B  57  38  86  87
# Joseph       E  67  87  87  93
# Alexander    C  91  76  26  79

# %%
# 单一条件
# df[df.Q1 > 90] # Q1列大于90的
# df[df.team == 'C'] # team列为'C'的
# df[df.index == 'Oscar'] # 指定索引即原数据中的name
# 组合条件
# df[(df['Q1'] > 90) & (df['team'] == 'C')] # and关系 
df[df['team'] == 'C'].loc[df.Q1>90] # 多重筛选
# Out:
#           team  Q1  Q2  Q3  Q4
# name
# Eorge        C  93  96  71  78
# Alexander    C  91  76  26  79
# Lincoln4     C  98  93   1  20

# %%
# df.sort_values(by='Q1') # 按Q1列数据升序排列 
# df.sort_values(by='Q1', ascending=False) # 降序
df.sort_values(['team', 'Q3'], ascending=[True, False]) # team升序 Q1 降序
# Out:
#          team  Q1  Q2  Q3  Q4
# name
# Lfie        A   9  10  99  37
# Blake       A  78  23  93   9
# Joshua      A  63   4  80  30
# Lucas       A  60  41  77  62
# Henry       A  91  15  75  17
# ...       ...  ..  ..  ..  ..
# Liver       E  89  21  24  64
# Teddy       E  71  91  21  48
# Jaxon       E  88  98  19  98
# Jackson5    E   6  10  15  33
# Jude        E   8  45  13  65
#
# [100 rows x 5 columns]

# %%
# df.groupby('team').sum() # 按团队分组对应列相加 
# df.groupby('team').mean() # 按团队分组对应列求平均 
# 不同列不同的计算方法 
df.groupby('team').agg({'Q1': sum, # 总和
'Q2': 'count', # 总数 
'Q3':'mean', # 平均 
'Q4': max}) # 最大值
# Out:
# /var/folders/yh/2mmdl1bn1jd99p0f21wbbch40000gp/T/ipykernel_47779/3811093103.py:4: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
#   df.groupby('team').agg({'Q1': sum, # 总和
# /var/folders/yh/2mmdl1bn1jd99p0f21wbbch40000gp/T/ipykernel_47779/3811093103.py:4: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'max' instead.
#   df.groupby('team').agg({'Q1': sum, # 总和
#         Q1  Q2         Q3  Q4
# team
# A     1066  17  51.470588  97
# B      975  22  54.636364  99
# C     1056  22  48.545455  98
# D      860  19  65.315789  99
# E      963  20  44.050000  98

# %%
df.groupby('team').sum().T
# Out:
# team     A     B     C     D     E
# Q1    1066   975  1056   860   963
# Q2     639  1218  1194  1191  1013
# Q3     875  1202  1068  1241   881
# Q4     783  1136  1127  1199  1033

# %%
# df['one'] = 1 # 增加一个固定值的列
# df['total'] = df.Q1 + df.Q2 + df.Q3 + df.Q4 # 增加总成绩列
# 将计算得来的结果赋值给新列
# df['total'] = df.loc[:,'Q1':'Q4'].apply(lambda x:sum(x), axis=1) df['total'] = df.sum(axis=1) # 可以把所有为数字的列相加
# df['avg'] = df.total/4 # 增加平均成绩列

# %%
import matplotlib
# df['Q3'].plot()
df.loc['Riley','Q1':'Q4'].plot() # ben四个季度的成绩变化
# Out:
# <Axes: >

# %%
# df.loc[ 'Ben','Q1':'Q4'].plot.bar() # 柱状图 
df.loc[ 'Ben','Q1':'Q4'].plot.barh() # 横向柱状图
# Out:
# <Axes: >

# %%
# 各Team四个季度总成绩趋势 
df.groupby('team').sum().T.plot()
# Out:
# <Axes: >

# %%
# 各组人数对比 
df.groupby('team').count().Q1.plot.pie()
# Out:
# <Axes: ylabel='Q1'>
